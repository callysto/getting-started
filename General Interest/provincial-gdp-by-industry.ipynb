# %% [markdown]
# ## Provincial GDP by Industry

# %% [markdown]
# This notebook explores gross domestic product [data released by Statistics Canada on 2018-05-02](http://www.statcan.gc.ca/daily-quotidien/180502/dq180502a-eng.htm). The objective is to generate an overview of the 🇨🇦 economy, separated by provinces and industry sectors. The amounts are in `Chained (2007) dollars` (Millions).
#
# Specific Questions I want to understand:
#
# + What are the top 10 industry sector line items in Canada?
# + What are the top 10 industry sector line items in each province?
#
# > Author: [J. Colliander](http://colliand.com)
# > Date: 2018-05-03

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## The data was downloaded from StatsCan.
## The first 3 rows contain header information that we don't want in the data frame.
## The last 28 rows contain footnotes and information about the data set. We don't want those in the frame.
## skipfooter seemed to require changing the engine from default 'c' to 'python'.
gitems = pd.read_csv('./data/cansim-3790030-eng-4789079444265787071.csv', skiprows = 3, skipfooter = 28, engine='python')

# %%
## Throw away lines with internal Provincial and territorial totals.
## There may be other internal totals included here.
## TODO Review the footnotes and accompanying information on the data set.
df = gitems.loc[~(gitems['North American Industry Classification System (NAICS)'].str.contains('All industries'))]

# %%
df
# Out:
#                       Geography                   Value  \
# 0     Newfoundland and Labrador  Chained (2007) dollars
# 1     Newfoundland and Labrador  Chained (2007) dollars
# 2     Newfoundland and Labrador  Chained (2007) dollars
# 3     Newfoundland and Labrador  Chained (2007) dollars
# 4     Newfoundland and Labrador  Chained (2007) dollars
# 5     Newfoundland and Labrador  Chained (2007) dollars
# 6     Newfoundland and Labrador  Chained (2007) dollars
# 7     Newfoundland and Labrador  Chained (2007) dollars
# 8     Newfoundland and Labrador  Chained (2007) dollars
# 9     Newfoundland and Labrador  Chained (2007) dollars
# 10    Newfoundland and Labrador  Chained (2007) dollars
# 11    Newfoundland and Labrador  Chained (2007) dollars
# 12    Newfoundland and Labrador  Chained (2007) dollars
# 13    Newfoundland and Labrador  Chained (2007) dollars
# 14    Newfoundland and Labrador  Chained (2007) dollars
# 15    Newfoundland and Labrador  Chained (2007) dollars
# 16    Newfoundland and Labrador  Chained (2007) dollars
# 17    Newfoundland and Labrador  Chained (2007) dollars
# 18    Newfoundland and Labrador  Chained (2007) dollars
# 19    Newfoundland and Labrador  Chained (2007) dollars
# 20    Newfoundland and Labrador  Chained (2007) dollars
# 21    Newfoundland and Labrador  Chained (2007) dollars
# 22    Newfoundland and Labrador  Chained (2007) dollars
# 23    Newfoundland and Labrador  Chained (2007) dollars
# 24    Newfoundland and Labrador  Chained (2007) dollars
# 25    Newfoundland and Labrador  Chained (2007) dollars
# 26    Newfoundland and Labrador  Chained (2007) dollars
# 27    Newfoundland and Labrador  Chained (2007) dollars
# 28    Newfoundland and Labrador  Chained (2007) dollars
# 29    Newfoundland and Labrador  Chained (2007) dollars
# ...                         ...                     ...
# 1270                    Nunavut  Chained (2007) dollars
# 1271                    Nunavut  Chained (2007) dollars
# 1272                    Nunavut  Chained (2007) dollars
# 1273                    Nunavut  Chained (2007) dollars
# 1274                    Nunavut  Chained (2007) dollars
# 1275                    Nunavut  Chained (2007) dollars
# 1276                    Nunavut  Chained (2007) dollars
# 1277                    Nunavut  Chained (2007) dollars
# 1278                    Nunavut  Chained (2007) dollars
# 1279                    Nunavut  Chained (2007) dollars
# 1280                    Nunavut  Chained (2007) dollars
# 1281                    Nunavut  Chained (2007) dollars
# 1282                    Nunavut  Chained (2007) dollars
# 1283                    Nunavut  Chained (2007) dollars
# 1284                    Nunavut  Chained (2007) dollars
# 1285                    Nunavut  Chained (2007) dollars
# 1286                    Nunavut  Chained (2007) dollars
# 1287                    Nunavut  Chained (2007) dollars
# 1288                    Nunavut  Chained (2007) dollars
# 1289                    Nunavut  Chained (2007) dollars
# 1290                    Nunavut  Chained (2007) dollars
# 1291                    Nunavut  Chained (2007) dollars
# 1292                    Nunavut  Chained (2007) dollars
# 1293                    Nunavut  Chained (2007) dollars
# 1294                    Nunavut  Chained (2007) dollars
# 1295                    Nunavut  Chained (2007) dollars
# 1296                    Nunavut  Chained (2007) dollars
# 1297                    Nunavut  Chained (2007) dollars
# 1298                    Nunavut  Chained (2007) dollars
# 1299                    Nunavut  Chained (2007) dollars
#
#      North American Industry Classification System (NAICS)    2013    2014  \
# 0     Information and communication technology, manu...        7.9     7.5
# 1     Information and communication technology, serv...      659.9   669.7
# 2                Crop and animal production [11A]  (13)       96.0    61.7
# 3                            Forestry and logging [113]       71.0    74.4
# 4                   Fishing, hunting and trapping [114]      237.0   210.5
# 5     Support activities for agriculture and forestr...       22.0    20.9
# 6                          Oil and gas extraction [211]     5923.3  5534.6
# 7       Mining and quarrying (except oil and gas) [212]     2802.3  2361.2
# 8     Support activities for mining and oil and gas ...      200.5   205.0
# 9     Electric power generation, transmission and di...      528.0   520.6
# 10    Natural gas distribution, water, sewage and ot...       35.7    35.3
# 11        Residential building construction [23A]  (20)      566.7   518.9
# 12    Non-residential building construction [23B]  (20)      407.4   352.8
# 13                 Engineering construction [23C]  (20)     1179.2  1496.1
# 14                      Repair construction [23D]  (20)      181.5   198.3
# 15    Other activities of the construction industry ...       14.4    15.4
# 16                             Food manufacturing [311]      273.0   271.6
# 17     Beverage and tobacco product manufacturing [312]       97.6    97.8
# 18        Textile and textile product mills [31A]  (23)        2.5     3.0
# 19    Clothing and leather and allied product manufa...       16.8    14.5
# 20                     Wood product manufacturing [321]       19.3    17.3
# 21                            Paper manufacturing [322]       32.7    47.3
# 22        Printing and related support activities [323]       13.3    10.2
# 23       Petroleum and coal product manufacturing [324]      321.6   261.2
# 24                         Chemical manufacturing [325]        9.9     5.8
# 25     Plastics and rubber products manufacturing [326]       14.5    14.6
# 26     Non-metallic mineral product manufacturing [327]       20.1    22.2
# 27                    Primary metal manufacturing [331]        0.2     0.1
# 28         Fabricated metal product manufacturing [332]       62.7    86.5
# 29                        Machinery manufacturing [333]       18.5    23.2
# ...                                                 ...        ...     ...
# 1270                   Other information services [519]        0.0     0.0
# 1271  Depository credit intermediation and monetary ...       20.2    20.3
# 1272        Non-depository credit intermediation [5222]        2.9     2.9
# 1273  Activities related to credit intermediation [5...        0.6     0.0
# 1274    Insurance carriers and related activities [524]        8.3     8.4
# 1275  Financial investment services, funds and other...        5.4     5.1
# 1276                                  Real estate [531]      208.0   205.6
# 1277                  Rental and leasing services [532]        4.6     3.2
# 1278  Lessors of non-financial intangible assets (ex...        0.0     0.0
# 1279  Legal, accounting and related services [541A] ...        7.3     6.7
# 1280  Architectural, engineering and related service...        6.6     7.8
# 1281  Other professional, scientific and technical s...        9.3     9.3
# 1282  Computer systems design and related services [...        1.1     1.3
# 1283  Advertising, public relations, and related ser...        0.0     0.0
# 1284          Administrative and support services [561]       36.1    33.1
# 1285    Waste management and remediation services [562]       10.5    10.9
# 1286                                Universities [6113]        0.0     0.0
# 1287  Educational services (except universities) [61...      153.3   156.6
# 1288                            Health care [62X]  (49)       84.3    85.8
# 1289                            Social assistance [624]       27.7    28.6
# 1290  Performing arts, spectator sports and related ...        0.1     0.1
# 1291  Amusement, gambling and recreation industries ...        2.0     0.9
# 1292                       Accommodation services [721]       17.3    15.8
# 1293            Food services and drinking places [722]        9.1     7.9
# 1294                       Repair and maintenance [811]        1.8     1.8
# 1295  Personal services and private households [81A]...        2.5     2.4
# 1296  Religious, grant-making, civic, and profession...       18.3    18.3
# 1297     Federal government public administration [911]       72.5    75.8
# 1298  Provincial and territorial public administrati...      216.0   223.0
# 1299  Local, municipal, regional and aboriginal publ...       87.1    85.5
#
#         2015    2016    2017
# 0        6.4     6.6     8.4
# 1      668.3   671.1   676.1
# 2       93.5   103.5    88.6
# 3       72.0    68.5    69.7
# 4      203.5   186.0   154.8
# 5       22.8    21.2    20.8
# 6     4677.1  5787.4  6076.8
# 7     2810.5  2701.8  2756.6
# 8      193.6   205.9   238.3
# 9      560.9   565.5   577.0
# 10      35.2    35.4    35.4
# 11     464.8   419.8   396.3
# 12     366.8   228.6   195.8
# 13    1506.1  1517.3  1680.5
# 14     178.9   182.7   182.1
# 15      14.6    12.4    12.6
# 16     274.1   272.9   267.8
# 17      95.2    95.0    95.2
# 18       5.1     6.3     7.6
# 19       4.1     5.1     4.4
# 20      16.6    18.6    19.1
# 21      44.6    40.3    40.2
# 22      10.7    10.6    10.2
# 23     289.0   275.3   336.8
# 24       7.2     8.9    11.7
# 25      15.1     8.1     7.4
# 26      31.2    35.6    39.1
# 27      25.9    47.1    90.3
# 28      79.3    42.8    14.2
# 29      17.7    15.8    16.3
# ...      ...     ...     ...
# 1270     0.0     0.0     0.0
# 1271    20.6    22.1    22.6
# 1272     3.0     3.3     3.8
# 1273     0.0     0.0     0.0
# 1274     8.1     8.2     8.5
# 1275     5.2     4.8     5.7
# 1276   213.2   217.3   217.6
# 1277     3.0     3.2     3.5
# 1278     0.0     0.0     0.0
# 1279     5.8     6.1     6.2
# 1280     4.1     4.4     5.0
# 1281    10.0     9.8     9.8
# 1282     1.0     0.4     0.4
# 1283     0.0     0.0     0.0
# 1284    33.5    33.8    33.0
# 1285    10.1    10.8    10.6
# 1286     0.0     0.0     0.0
# 1287   159.9   159.2   161.6
# 1288    86.5    89.5    91.3
# 1289    28.6    30.5    31.6
# 1290     0.1     0.1     0.1
# 1291     0.8     0.8     0.8
# 1292    17.6    17.6    17.6
# 1293     8.2     8.2     8.3
# 1294     2.2     1.9     2.0
# 1295     2.4     2.4     2.4
# 1296    18.3    18.2    17.6
# 1297    75.8    76.1    77.7
# 1298   230.6   239.5   245.4
# 1299    91.1    91.2    92.4
#
# [1300 rows x 8 columns]

# %%
years = ['2013', '2014','2015', '2016', '2017']

# %%
## Total GDP vs Years
for year in years:
    print(year, df[year].sum())
# Out:
# 2013 1651662.1
# 2014 1702241.2
# 2015 1722884.8
# 2016 1749041.7
# 2017 1810391.1

# %%
df['Geography'].unique()
# Out:
# array(['Newfoundland and Labrador', 'Prince Edward Island', 'Nova Scotia',
#        'New Brunswick', 'Quebec', 'Ontario', 'Manitoba', 'Saskatchewan',
#        'Alberta', 'British Columbia (66)', 'Yukon',
#        'Northwest Territories', 'Nunavut'], dtype=object)

# %%
## long column label.
df = df.rename(columns={'North American Industry Classification System (NAICS)': 'NAICS'})

# %%
df.columns
# Out:
# Index(['Geography', 'Value', 'NAICS', '2013', '2014', '2015', '2016', '2017'], dtype='object')

# %%
## Industry sectors sorted by total value across all provinces and territories
df.groupby(['NAICS']).sum()['2017'].sort_values(ascending=False).head(n=25)
# Out:
# NAICS
# Real estate [531]                                                                211081.3
# Oil and gas extraction [211]                                                     112790.5
# Health care [62X]  (49)                                                          102038.9
# Information and communication technology, services [T015]  (11)                   73923.6
# Depository credit intermediation and monetary authorities [52B]  (37)             62887.0
# Educational services (except universities) [611B]  (47)                           57900.0
# Residential building construction [23A]  (20)                                     46072.0
# Local, municipal, regional and aboriginal public administration [91A]  (59)       39536.6
# Federal government public administration [911]                                    39427.4
# Administrative and support services [561]                                         37312.8
# Engineering construction [23C]  (20)                                              33773.2
# Universities [6113]                                                               32263.1
# Electric power generation, transmission and distribution [2211]                   31218.7
# Telecommunications [517]                                                          30520.9
# Provincial and territorial public administration [912]                            28867.6
# Machinery, equipment and supplies wholesaler-distributors [417]                   28134.7
# Insurance carriers and related activities [524]                                   27700.0
# Transportation equipment manufacturing [336]                                      27299.9
# Computer systems design and related services [5415]                               26886.7
# Food services and drinking places [722]                                           26583.2
# Mining and quarrying (except oil and gas) [212]                                   26303.0
# Food manufacturing [311]                                                          25389.5
# Repair construction [23D]  (20)                                                   24168.0
# Legal, accounting and related services [541A]  (44)                               22887.2
# Financial investment services, funds and other financial vehicles [52A]  (39)     22585.2
# Name: 2017, dtype: float64

# %%
## GDP vs Provinces
pd.pivot_table(df,index=['Geography'], 
               aggfunc = sum, 
               values = ['2017','2016','2015','2014','2013']).sort_values(by=['2017'], 
                ascending=[False]).plot(kind='bar', figsize=(10,6))

# %%
## 2017 Single Largest GDP Sector Sorted
pd.pivot_table(df,index=['NAICS'], 
               aggfunc = sum, values = ['2017','2016','2015','2014','2013']).sort_values(by=['2017'], 
                ascending=[False]).head(n=10).plot(kind='bar', figsize=(10,6))

# %%
## 2017 GDP vs Sector separated by Geography and sorted by maximum value
pd.pivot_table(df,index=['Geography', 'NAICS'], 
               aggfunc = max, values = ['2017']).sort_values(by=['2017'], ascending=[False]).head(n=25)
# Out:
#                                                                              2017
# Geography             NAICS
# Alberta               Oil and gas extraction [211]                        88076.7
# Ontario               Real estate [531]                                   82537.1
# British Columbia (66) Real estate [531]                                   39344.0
# Ontario               Health care [62X]  (49)                             37921.0
# Quebec                Real estate [531]                                   36320.8
# Ontario               Information and communication technology, servi...  33153.6
#                       Depository credit intermediation and monetary a...  32935.4
# Alberta               Real estate [531]                                   27700.6
# Ontario               Educational services (except universities) [611...  23007.8
# Quebec                Health care [62X]  (49)                             22248.7
# Ontario               Transportation equipment manufacturing [336]        18996.7
#                       Federal government public administration [911]      18706.4
#                       Administrative and support services [561]           17501.8
#                       Residential building construction [23A]  (20)       17269.2
# Quebec                Information and communication technology, servi...  15752.5
# Ontario               Local, municipal, regional and aboriginal publi...  15511.9
#                       Insurance carriers and related activities [524]     14801.4
# Alberta               Health care [62X]  (49)                             13779.3
# Ontario               Universities [6113]                                 13757.2
#                       Computer systems design and related services [5...  13612.8
#                       Machinery, equipment and supplies wholesaler-di...  12865.0
# British Columbia (66) Health care [62X]  (49)                             12842.3
# Quebec                Electric power generation, transmission and dis...  12228.1
#                       Educational services (except universities) [611...  12117.2
# Ontario               Financial investment services, funds and other ...  11837.2

# %%
## 2017 Individual Lines Items in the GDP breakdown of Geography X Sector
pd.pivot_table(df,index=['Geography','NAICS'], 
               aggfunc = sum, values = ['2017','2016','2015','2014','2013']).sort_values(by='2017', ascending=False).head(n=10).plot(
                kind='bar', figsize=(10, 6))

# %% [markdown]
# The GDP from `Alberta, Oil and gas extraction [211]` is comparable to the GDP from `Ontario, Real estate [531]`. The GDP from `British Columbia (66), Real Estate [531]` is about half the size of the contribution from Alberta Oil and Gas and Ontario Real Estate.

# %% [markdown]
# ## Analyze Provincial GDP across Sectors

# %%
df['Geography'].unique()
# Out:
# array(['Newfoundland and Labrador', 'Prince Edward Island', 'Nova Scotia',
#        'New Brunswick', 'Quebec', 'Ontario', 'Manitoba', 'Saskatchewan',
#        'Alberta', 'British Columbia (66)', 'Yukon',
#        'Northwest Territories', 'Nunavut'], dtype=object)

# %%
provinces = ['Newfoundland and Labrador', 'Prince Edward Island', 'Nova Scotia',
       'New Brunswick', 'Quebec', 'Ontario', 'Manitoba', 'Saskatchewan',
       'Alberta', 'British Columbia (66)', 'Yukon',
       'Northwest Territories', 'Nunavut']

# %%
whichprovince = 'British Columbia (66)'
pd.pivot_table(df.loc[df['Geography']== whichprovince],index=['NAICS'], 
               aggfunc = sum, values = ['2017','2016','2015','2014','2013']).sort_values(by='2017', ascending=False).head(n=20).plot(
                kind='bar', cmap="viridis", figsize=(16, 10), title= whichprovince)

# %%
whichprovince = 'Alberta'
pd.pivot_table(df.loc[df['Geography']== whichprovince],index=['NAICS'], 
               aggfunc = sum, values = ['2017','2016','2015','2014','2013']).sort_values(by='2017', ascending=False).head(n=20).plot(
                kind='bar', cmap="viridis", figsize=(12, 7), title= whichprovince)

# %%
whichprovince = 'Alberta'
pd.pivot_table(df.loc[df['Geography']== whichprovince],index=['NAICS'], 
               aggfunc = sum, values = ['2017']).sort_values(by='2017', ascending=False).head(n=15).plot(
                kind='pie', subplots=True, title= whichprovince, legend=False, figsize=(6,6), autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f451318cd68>], dtype=object)

# %%
whichprovince = 'Ontario'
pd.pivot_table(df.loc[df['Geography']== whichprovince],index=['NAICS'], 
               aggfunc = sum, values = ['2017']).sort_values(by='2017', ascending=False).head(n=10).plot(
                kind='pie', subplots=True, title= whichprovince, legend=False, figsize=(6,6), autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f45131142e8>], dtype=object)

# %%
whichprovince = 'British Columbia (66)'
pd.pivot_table(df.loc[df['Geography']== whichprovince],index=['NAICS'], 
               aggfunc = sum, values = ['2017']).sort_values(by='2017', ascending=False).head(n=10).plot(
                kind='pie', subplots=True, 
                title= whichprovince, legend=False, autopct='%1.1f%%', radius=1, figsize =(6,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4513084860>], dtype=object)

# %%
## This code creates a pivot table. Drag the column headings and play with the drop down menus to explore.
from pivottablejs import pivot_ui
pivot_ui(df)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
